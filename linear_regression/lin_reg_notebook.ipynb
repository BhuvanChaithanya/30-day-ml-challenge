# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Experience-Salary.csv')

# %%
df.head()
# Out:
#    exp(in months)  salary(in thousands)
# 0       18.290293             16.521825
# 1       17.023407             11.666234
# 2       26.343613             23.167255
# 3       19.105834             20.877145
# 4       27.742516             23.166236

# %%
len(df)
# Out:
# 1000

# %%
df.isnull().sum()
# Out:
# exp(in months)          0
# salary(in thousands)    0
# dtype: int64

# %%
plt.scatter(df['exp(in months)'], df['salary(in thousands)'])

# %%
#correlation of exp and salary
df.corr()
# Out:
#                       exp(in months)  salary(in thousands)
# exp(in months)              1.000000              0.810969
# salary(in thousands)        0.810969              1.000000

# %%
sns.pairplot(df)

# %%
## independent and dependent variable
X = df[['exp(in months)']] ##independent variable should be in 2D array or a dataframe
y = df['salary(in thousands)'] ##dependent variable can be in 1D array or a series

# %%
print(type(X))
print(type(y))
print(X.shape)
print(y.shape)
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.Series'>
# (1000, 1)
# (1000,)
